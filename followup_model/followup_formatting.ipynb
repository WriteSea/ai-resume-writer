# %%
import pandas as pd
import numpy as np
from openai import OpenAI
import json
import ast

# %%
followup_df = pd.read_csv('followup_ques_uncategorized.csv')
followup_df = followup_df[followup_df.order_id.notnull()]
followup_df = followup_df.drop_duplicates(subset=['order_id'], keep='first').reset_index(drop=True)
followup_df
# Out:
#                      order_id  \
# 0    5ff575580438d7001357b80e
# 1    5ffc729d0d564400125bcc31
# 2    5ff893a5dd2f9600139ab166
# 3    5ff8945fdd2f9600139ab16a
# 4    5ff7cd94dd2f9600139ab137
# ..                        ...
# 987  63ab370268746a00137ab45e
# 988  63c57f42d28912001b92f8fb
# 989  63c71397a837f6001a206708
# 990  63c57a469cac930013a54719
# 991  63c99ddaa837f6001a239c0a
#
#                               additional_questionnaire
# 0    {"1: Follow Up Questions ": {"1: Your current ...
# 1    {"1: Follow Up Questions ": {"1: Your current ...
# 2    {"1: Follow Up Questions ": {"1: GENERAL: In o...
# 3    {"1: Follow Up Questions ": {"1: Your current ...
# 4    {"1: Follow Up Questions ": {"1: Just a note: ...
# ..                                                 ...
# 987  {"1: Follow Up Questions": {"1: Your current L...
# 988  {"2: General Questions": {"1: What are you typ...
# 989  {"1: Follow Up Questions": {"1: Is the resume ...
# 990                                                 {}
# 991                                                 {}
#
# [992 rows x 2 columns]

# %%
categorize_followup_questions = """Given a JSON object containing various follow-up questions and answers related to personal information, work experience, education, skills, and other experiences (questions about awards, certifications, volunteering experiences, personal projects, and professional affiliations that are not work experiences), your task is to categorize these questions into separate lists for each of the 5 categories. 
For work experience, education, and other experiences, rewrite each question to include the job or degree or experience name in the question itself, eliminating the nested JSON format. Please note that "other experiences" refer to questions about awards, certifications, volunteering experiences, personal projects, and professional affiliations only. You will be rewarded for not putting any other question in the "other experience" section apart from the ones mentioned above. Questions related to career goals should strictly be placed under personal information. You will be rewarded for correctly categorizing each question and for not omitting any questions/answer pairs.

Finally, return a JSON object with keys for personal information, work experience, education, skills, and other experiences, each containing a list of the categorized questions along with answers (as shown in the schema below). 
{
  "personal_info": [string of correctly categorized question+answer],
  "work_experience": [string of correctly categorized question+answer],
  "education": [string of correctly categorized question+answer],
  "skills": [string of correctly categorized question+answer],
  "other_experience":[string of correctly categorized question+answer]
}

Here is the JSON object containing the follow-up questions and answers:
"""

# %%
def _get_model_output(followup_value):
    client =  OpenAI(
    api_key="",
)
    response = client.chat.completions.create(
            model="gpt-4o",
            messages = [
        {"role": "system", "content": "You specialize in categorizing question-answer pairs accurately to 5 categories, namely, personal information, work experience, education, skills, and other experiences."},
        {"role": "user", "content": categorize_followup_questions + followup_value}
    ], 
    response_format={"type": "json_object"}
            )
    result = response.choices[0].message.content
    return result

# %%
res = []
for id, row in followup_df.iterrows():
    followup_ques = row['additional_questionnaire']
    response = _get_model_output(followup_ques)
    print (id, response)
    res.append(response)
# Out:
# 0 {
#   "personal_info": [
#     "1: Your current LinkedIn URL is not customized. Customized URLs are important because they look more professional and make your profile more accessible to recruiters and hiring managers. The LinkedIn URL Linkedin.com/in/quinngawronski/ is available. I am going to add that URL to your resume. We recommend you update your URL on your LinkedIn account to this. Does this make sense? : Yes"
#   ],
#   "work_experience": [
#     "Social Media and Marketing Intern – Outpost Club: What key networks did your social media strategy span across? : Do you mean what platforms? My strategy was for Facebook, Instagram and email marketing",
#     "Social Media and Marketing Intern – Outpost Club: How frequently were you developing marketing email campaigns and newsletters? Do you have any data to show an increase in open rates or something similar?  : As needed — there are some weeks where we send out three and weeks where there are none. Last year our open rate increased by 6.2%, our click rate increased by 7.8%",
#     "Social Media and Marketing Intern – Outpost Club: Were you conducting SEO research for these blog posts? Were you tracking trends to determine blog topics? Were you in charge of posting these articles? Do you have any quantitative data suggesting the reach of these articles? : I was tracking trends, but didn't do SEO research for this particular role. I didn't post articles but I put them in the back end of the website for publishing (Nebo) I don't have any data about the articles at the moment but I asked my boss — they're kind of buried in the website so I don't expect them to have a great reach",
#     "Editor in Chief – University Girl Magazine: How did you effectively manage 200 members?  : I scheduled meetings and led weekly meetings where we broke into smaller groups to brainstorm article ideas and do edits, we used Google sheets to track submitted drafts which were then automatically sent to editors, sent weekly emails to update members on tasks if they were unable to attend meetings, created a semester calendar with shoots, draft due dates, and launch dates and assigned articles/graphics accordingly.",
#     "Editor in Chief – University Girl Magazine: How many articles did you edit in total for the four print magazines?  : I actually edited 3 now that I'm looking at it — I edited all 146 total pages for graphics, spelling etc and edited 41 total articles.",
#     "Editor in Chief – University Girl Magazine: What remote editing strategies did you implement? : We used Google Docs to make suggested edits and track changes, I would have 2-3 people go in and make edits and I would approve edits if I agreed with them. Each time we did this we looked for different types of errors like line edits, structural, fact-checking, etc so nothing would be missed",
#     "Digital News intern – NBC News: How did you determine what articles to pitch and report on? What trends did you track and how did you track them? : I used PR releases, AP News, Reuters, and Facebook and Google Analytics to see what stories were trending and performing well online. They did have to fit within our diversity vertical coverage, so if there was some component that focused on race or sexuality usually we could write about it.",
#     "Digital News intern – NBC News: Can you explain more of what your responsibilities were when working on the Democratic presidential debate? : I monitored Twitter and sent updates and quotes to the live bloggers who run the ongoing coverage which is posted in blurbs as the debate happens. I was in tune to the hashtags and key figures (politicians, journalists, etc) to forward along any notable remarks",
#     "Digital News intern – NBC News: How did you manage Instagram posts? Were you creating these graphics or monitoring a content calendar?  : I posted on the NBC Instagram — we aimed to promote one article per post and posted 3-5 times per week. There was no content calendar. The graphics were typically used within the article, I would select the photo and draft a caption for approval prior to posting.",
#     "Digital News intern – NBC News: What did your collaboration with section editors entail?  : They approved my pitches, assigned me stories to write, edited my articles in Google Docs, and published my final stories. I also assisted with finding sources/contacts to interview and helped with research for their articles.",
#     "Editorial Intern – Swirled Magazine: Do you have any quantitative data to show the reach of this newsletter’s audience? : ",
#     "Editorial Intern – Swirled Magazine: What was the impact of your efforts optimizing commerce posts? Did you see an increase in engagement or something similar? If yes, do you have any data to show that? : ",
#     "Editorial Intern – Swirled Magazine: Do you have any data on how many visitors went to the magazine's homepage each week/month? : ",
#     "Writing Intern – Society 19 Magazine: How did you determine what content to include in these 40+ articles? : I usually selected topics that I found personally interesting, or that I had noticed were trending on social media (fad diets, seasonal articles, college life etc)",
#     "Writing Intern – Society 19 Magazine: Were the 4,400 shares you received a direct result of your employment of SEO guidelines? : That and it was a trending topic - Valentine's Day makeup looks",
#     "Section Editor - Medley: When reporting on culture and politics in Syracuse, were you conducting interviews and field research? Were you attending conferences/public hearings/etc.?  : Yes, I attended town halls and public forums where I interviewed people and conducted field research. I wrote extensively on a local drag bar and interviewed queens at the bar as well (featured as cover story)",
#     "Section Editor - Medley: Approx. how many articles did you review for the two print issues? : Approx 16 articles",
#     "Section Editor - Medley: Can you tell me more about the feature article you wrote and what went into developing this article? : I wrote two feature articles for Medley, the first one was on the local drag community in Syracuse. I went to a drag show and interviewed three drag performers, transcribed interviews, and conducted research. For the second feature article I wrote I discussed lead exposure in the city of Syracuse — I spoke to Common Councilors, attended a public forum for concerned citizens where I interviewed people, interviewed construction company employees who treat lead exposure, and interviewed a local doctor who treats lead poisoning in children.",
#     "Campus Life and Health Editor - Equal Time Magazine: How did you effectively lead this team of three writers? : I assigned them weekly articles and approved or edited their pitches. I would provide feedback and edits on a set date so they had time to make changes to the article before the final deadline.",
#     "City Beat Writer - The Daily Orange: How did you connect with residents, politicians, and activists for interviews? Were you leveraging existing connections? : I attended a city hall meeting and spoke to members of the city's innovation team, common councilors, and mayor Ben Walsh. I had to build these connections but continued to leverage them for my work with Medley"
#   ],
#   "education": [],
#   "skills": [
#     "Are you familiar with Microsoft Office Suite (Word, PowerPoint, Excel, Outlook)? : Yes",
#     "You listed content management systems (CMS) on your current resume. Are there any specific software programs you’ve used that you would like us to include on your new resume? : Wix, Squarespace, WordPress, NeBo"
#   ],
#   "other_experience": []
# }
# 1 {
#   "personal_info": [
#     "Your current LinkedIn URL is not customized. Customized URLs are important because they look more professional and make your profile more accessible to recruiters and hiring managers. The LinkedIn URL Linkedin.com/in/lorenzo.smith is available. I am going to add that URL to your resume. We recommend you update your URL on your LinkedIn account to this. Does this make sense? - www.linkedin.com/in/lorenzo--smith"
#   ],
#   "work_experience": [
#     "Captivate: Sales Planner - Can you please describe the role you had in the actual media campaigns you made end-of-campaign reports for? Please go into detail about the campaigns you led and/or took a part of, as well as the results of the campaigns. Were you working on multiple campaigns at once? What effect did they have on the companies? - I work with 6 account executives and each of them have various campaigns that run throughout the year. It varies by how many campaigns they book. I would say at least 20 campaigns a year. The campaign report states campaign objectives, impressions delivered, POP shots, If it had a retargeting portion it would also include impressions and CTR by Device/Day and Time/Creative Size",
#     "Captivate: Sales Planner - What kinds of tactics did you suggest and implement to engage with the target audience? Who was the target audience? - The target audience varies drastically by campaign. Our most targeted audience are affluent office workers with a HHI of $100K+. We mainly used Dstillery segments to locate specific audiences in our network. Here's a few Dstillery examples (C-Suite Executives, Business Decision Makers, Nurses, etc)",
#     "Captivate: Sales Planner - Are you able to quantify how successful you were at hitting clients’ KPIs, and how did you ensure you were on track? Please go into detail about the media plans that were successful, and the results for the client(s). How many clients were you working for? - KPI's varies drastically from campaign to campaign. Our main goal is to make sure all campaigns delivered their impressions in full.",
#     "Captivate: Sales Planner - Can you describe a bit more how you used DOOH media marketing in this role? - Captivate is strictly a DOOH media company. We place digital ads in elevators and lobbies of Office Buildings",
#     "MiQ: Sales Planner - What kinds of businesses did you develop during pre-sale periods, and what kinds of strategic plans did you implement? What were the ultimate results of these strategies? How successful were they? - MiQ is strictly a programmatic company but we had various products (Native, Video, Rich Media, etc). So we would discuss during the presale process, what product delivers on the specific goals that the client had. Success depended on the goals that the client has, some wanted strictly awareness and some wanted high CTR.",
#     "MiQ: Sales Planner - How did you uphold the production process? In other words, what were your duties/what programs did you use to manage the operational excellence? - I had to loop in multiple departments in discussions around campaigns to make sure what we are proposing is doable",
#     "MiQ: Sales Planner - Can you describe the role you played in building the programmatic proposals? - My job was to build the media plans and media decks that the account executives used to pitch our programmatic products.",
#     "MiQ: Sales Planner - In what specific ways did you ensure KPI delivery? - We monitored these plans with the Traders daily and made adjustments to the targeting to ensure KPI delivery",
#     "Liberty Sport: Regional Chain Sales Coordinator - What exactly did you research to generate additional business? What kinds of additional business did you generate? - My job was to use google to search for Optical Chains in various states throughout the country and align them with our Sales Reps to determine their needs and generate new business",
#     "Liberty Sport: Regional Chain Sales Coordinator - Can you advise what software you used to create the pivot tables? - I used excel to create the pivot tables",
#     "Liberty Sport: Regional Chain Sales Coordinator - How did you determine success and opportunities for growth for optical chains? - We looked at the existing sales of the client compared to other comparable optical chains to determine what products would increase their sales potential.",
#     "Premium Retail Services: Google Specialist - What were you responsible for setting deadlines for? How many deadlines were you responsible for setting and adhering to at a time (if you’re able to quantify this)? - I set deadlines and meetings on product successes with store managers to discuss product goals. I set about 3 -5 meetings a week",
#     "Premium Retail Services: Google Specialist - Can you go into detail about the kind of work you did independently? What exactly did you do to contribute to driving sales? - My job was to drive to these locations and educate the management team on google products and be their point person on how best to sell the products. I also audited the product displays to make sure the products were in the best possible position to succeed. I monitored sales and assisted stores with low sell rates.",
#     "Premium Retail Services: Google Specialist - How many stores were you the point person for? - I was the point person for about 15 stores (Walmart, Best Buy, Staples, and Target)",
#     "Toys R Us Express: Assistant Store Manager - How were you responsible for store sales? What specific responsibilities did you have? - We had specific daily sales quota's for the store. My job was to make sure we hit that by helping the staff sell as many toys as possible and sign up as many people for the ToysRus credit card",
#     "Toys R Us Express: Assistant Store Manager - Can you describe the scope of the assignments you prioritized? What materials/reports did you present, and who did you present these to? How often did you make these presentations? - I didn't present any reports in this role. My assignments were managing the team to change out presentations in the store weekly. This is the big displays and endcaps in the store",
#     "Toys R Us Express: Assistant Store Manager - How many new associates did you manage and train? - I onboarded and managed about 20 associates"
#   ],
#   "education": [],
#   "skills": [
#     "Can you please advise if you have experience with any other computer programs/software aside from the ones listed under 'Computer Proficiencies' in the resume provided? For example, do you have experience using DoubleClick or the Nielsen suite? - DV360 and Nielsen"
#   ],
#   "other_experience": []
# }
# 2 {
#   "personal_info": [
#     "GENERAL: In optimizing your resume, we will be emphasizing your accomplishments and articulating their impact in a more specific, quantitative, and qualitative way. Please answer the following questions to communicate further your strengths in the resume we will create for you. : ",
#     "Would you like to add anything else not mentioned in your previous questionnaire? : No. The new job posting I added has a lot of my current responsibilities.",
#     "Target Jobs: The following job listing you provided is no longer taking applicants. Would you like to send another target job link? If you do, please paste the link on the space below. Taken:  https://www.linkedin.com/jobs/search/?currentJobId=2375152259&amp;pivotType=jymbii&amp;start=0&amp;redirect=false : https://www.linkedin.com/jobs/view/2370226874/?refId=f36c1901-c3b9-4e58-94d2-3ee5b2a86bb6"
#   ],
#   "work_experience": [
#     "Director, Global Quality Management: What departments or approximately how many teams did you work with to develop processing management of the adverse event and product quality complaints? How many members did the senior management team have? : 1) I had to work cross functionally with site Quality Assurance, Drug Safety, PV, Scientific Affairs and Regulatory Affairs. 2) Each department had approximately 2 representatives assigned to this project - one, typically the VP or Director level and one analyst.",
#     "Director, Quality Management: In timely improving quality system policies and procedures, what were some specific goals or target figures you could reference for these accomplishments? It will allow the reader to understand better the impact of the achievement you have executed. What are the tools and techniques you utilized to help you develop training programs and processes? How many staff members were supervising? What were the goals of the training? : 1. One of the major tasks I had was improving on time closure of site deviations. At the time I was hired in the role (July 2018), the site was closing 50% of their deviations within the required dates as outlined per procedure. By the end of Dec 2019, the site on time deviation closure improved to 90%. I utilized weekly compliance meetings to drive improvements. 2) The site utilized a manual training system. I created department specific training curriculum and generated a list by title for each employee. The employees were tasked with completing certain procedures each month, and we met quarterly to review the progress. 3) I had 5 direct reports - two senior managers, 2 Manager, 1 Senior Specialist, and 1 Coordinator. The two senior managers were responsible for 7 other employees. The goals of the training was to insure site level GMP compliance and to make sure the staff were knowledgeable in tasks related to their responsibilities."
#   ],
#   "education": [],
#   "skills": [],
#   "other_experience": []
# }
# 3 {
#   "personal_info": [
#     "1: Your current LinkedIn URL is not customized. Customized URLs are important because they look more professional and make your profile more accessible to recruiters and hiring managers. The LinkedIn URL Linkedin.com/in/lizann-thompson is available. I am going to add that URL to your resume. We recommend you update your URL on your LinkedIn account to this. Does this make sense? : yes. Please advise on how.",
#     "8: It is recommended that jobs that have been completed for 10 years or more, be excluded from the resume. There is limited space on an optimized resume, so the positions that ended during or before 2010 will not be present on your resume. However, these positions are still important to include on your LinkedIn. Does this make sense? : yes",
#     "\"8: \"\"Accomplishments\" is a section that would be a better fit to be included on LinkedIn, rather than on the resume. Instead, we will have a section for your certifications, which is something that employers often look for. : ok - thanks\"",
#     "8: It is recommended that a professional summary be excluded from a resume, especially if there is ample information on your resume that showcases your experience in an industry. In addition, your professional summary can be found by employers on your LinkedIn page. Does this make sense? : yes, can you still create a summary for linkedin?"
#   ],
#   "work_experience": [
#     "Saul Centers Inc - Park Van Ness (General Manager): Is the title of your current job most accurately written Saul Centers Inc - Park Van Ness? If not, what is the correct way for it to be written on your resume? : Park Van Ness - Saul Centers Inc. for the resume but Saul Centers alone for the Linkedin profile. Saul Centers Inc is the holding company - pvn is the property location i manage",
#     "Saul Centers Inc - Park Van Ness (General Manager): Was increasing rent and fees the only cause of the increase of NOI? If not, what else did you do that contributed to achieving this? : reduced expenses by bidding out projects and assigning the most cost effective and efficient vendor. lower turn over reduce vacancy loss",
#     "Saul Centers Inc - Park Van Ness (General Manager): Do you have an estimate of how much ($ or %) you surpassed your NOI target, or how much ($ or %) it increased from the prior year? : I need to get this data",
#     "Saul Centers Inc - Park Van Ness (General Manager): What other ways have you caused an increase in revenue? (If any) : a focus on capturing miscellaneous income and charging term fees accordingly",
#     "Saul Centers Inc - Park Van Ness (General Manager): How often do you reconcile accounts? Approximately how many accounts are there? : weekly, prior to month end and reconcile move in accounts by the 4th of each month. move out accounts by the 28th of each month. 271 accounts.",
#     "Saul Centers Inc - Park Van Ness (General Manager): Did you personally implement the proactive communications and payment plan options that decreased delinquency, or did these communications and payment plans exist prior? If they existed prior, were they not being implemented properly prior to you? : SOP's were in place however I reenforced the proper practice/use by outlining firm follow up deadlines and follow up strategies for collecting outstanding balances. I created a deposit accounting checklist which also aided in the proper reconciling of move out accounts - this also contributed to revenue whereby charge opportunities were not missed.",
#     "Saul Centers Inc - Park Van Ness (General Manager): What were the key contributions that you would credit for reducing the occupancy turnover rate? : replaced underperforming staff with high performers. improved response time, resolution and follow up to work orders presented resident renewals in a timely fashion allowing for adequate review time by the resident improved the quality and frequency of events increased resident engagement on the community rewards portal by engaging the residents in polls offered weekly on site yoga more frequent community communication updates regarding projects, events and general reminders more timely and professional response to resident queries increased management availability and accessibility to resident concerns",
#     "Saul Centers Inc - Park Van Ness (General Manager): What actions did you take that contributed to the increase in service ratings? : empowered, trained, provided template responses for challenging questions to team members resulted in more satisfactory resolutions replaced under performing staff with high performers. improved response time, resolution and follow up to work orders presented resident renewals in a timely fashion allowing for adequate review time by the resident improved the quality and frequency of events increased resident engagement on the community rewards portal by engaging the residents in polls offered weekly on site yoga more frequent community communication updates regarding projects, events and general reminders more timely and professional response to resident queries increased management availability and accessibility to resident concerns",
#     "Saul Centers Inc - Park Van Ness (General Manager): How were you able to reduce your actual expenditures to be less than your budget? (1-2 ways if applicable) : conducting inventories of equipment and supplies prior to spending successfully bidding out projects and awarding the project to the most cost-effective quality vendor negotiated pricing with vendors",
#     "Saul Centers Inc - Park Van Ness (General Manager): What was the impact of modifying the invoice approval workflow? (reduced error, streamlined the process, etc.) : assigning the appropriate lead associate to verify (first approver) on invoices allowed for more accurate payments to services rendered and the newly assigned personnel was able correctly verify the services rendered and the associate was the personnel ordering the service. This overall did streamline the process, became faster, reduced errors and was streamlined overall. The new associate approver felt more empowered and motivated.",
#     "Saul Centers Inc - Park Van Ness (General Manager): What actions did you take to effectively implement your COVID-19 service strategies? (the questionnaire lists the strategies you implemented, so my question is more along the lines of, how you ensured they were successful) : created my own checklist on what has to be done upon receiving a report of a positive case both for employees and residents. The checklist ensured that all was handled in the most confidential way. The execution time also became much faster.",
#     "Saul Centers Inc - Park Van Ness (General Manager): Were there any other responsibilities or achievements from this position that we haven’t discussed? (If no, you can say N/A) : ARM (Accredited Residential Manager)",
#     "Kennedy Warren Apartments (Assistant General Manager): Did you lead a group in analyzing and discussing preliminary market conditions? : I did not lead the group however I was involved in collecting the market survey data of our competitors and entering it into our system to present and discuss for our weekly pricing calls",
#     "Kennedy Warren Apartments (Assistant General Manager): Do you have an example of the impact of a marketing strategy that was successful? : more leases were derived from creating a sense of urgency and promoting the renovated kitchens as first use. Also indicating the benefits to leasing in a rent control building.",
#     "Kennedy Warren Apartments (Assistant General Manager): What steps did you take to achieve the highest profit margin YTD? : lead the team through a successful Leasing season during the summer for 3 months in the absence of the GM. This resulted in higher occupancy of 96% overall. Motivated leasing staff, created leasing strategies, set monthly leasing goals, managed the turnover process all during kitchen renovations for the property.",
#     "Kennedy Warren Apartments (Assistant General Manager): What was your role in budget development? : being involved in property walks and identifying areas for capital improvement, collecting competitive bids to get the most appropriate prices. negotiated contracts/pricing where possible. submitting all cost data",
#     "Kennedy Warren Apartments (Assistant General Manager): What are some ways that you minimized expenses? : shopped for lower priced inventory items such as office supplies monitored and curtailed overtime as needed overall repaired flooring during turnovers as need vs a replacement where suitable. same for freshening up carpet that is within its lifespan vs replacing upon each turnover. strategy purchasing - reduced purchase quantity when normal quantity isn’t necessary based on usage or increased purchase quantity where a bulk purchase discount was available. utilize discount codes as needed. negotiated costs with vendor where appropriate",
#     "Kennedy Warren Apartments (Assistant General Manager): What was involved in the evaluation of rental pricing strategies? What actions did you take to determine and implement new strategies? : involved in collecting the market survey data of our competitors and entering it into our system to present and discuss for our weekly pricing calls. identified system pricing and demand where skewed for correction.",
#     "Kennedy Warren Apartments (Assistant General Manager): How did you streamline the lease enforcement process? : by requesting leasing application files with a sense of urgency, review filed for accuracy confirming all signed forms and id verification was completed, verify income and background qualifications in a timely manner.",
#     "Kennedy Warren Apartments (Assistant General Manager): How did you coordinate vendor assignments? : overseeing scheduling of cabinet measurements, demolition, cabinet, flooring and appliances installation. done on a tracker and reviewed in weekly meetings with project mgr, coordinator and construction team.",
#     "Kennedy Warren Apartments (Assistant General Manager): Were ROI targets reached and/or surpassed in the renovation project? : the project is still ongoing to date but we were well on target",
#     "Kennedy Warren Apartments (Assistant General Manager): What was involved in preparing the weekly leasing reports? What was the overall purpose of preparing these? : extracting leasing activity and comparing the data week over week to monitor and manage property performance and availability",
#     "Kennedy Warren Apartments (Assistant General Manager): Were you in charge of coming up with a plan to alleviate budget variances? If so, what did this entail and what was the impact? : variances were all justified.",
#     "Kennedy Warren Apartments (Assistant General Manager): Are there any other quantitative achievements that we have not discussed? (If no, you can say N/A) : property leasing velocity was averaging 50%",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): How did you improve efficiency in guest service operations? (If it does not deviate from the answers in your questionnaire, you can say N/A here) : n/a",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): Do you have an estimate of how much operational expenses were reduced by? : 8%",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): How were inventory audits conducted? Was it a comparison of what was in the computer system with what was physically counted? : yes actual vs computer and reordering triggered of par level is reached",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): What efforts did you take to increase employee retention? : employee recognition and celebratory emails properly trained, empowered, motivated and supported staff",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): What did the day and night time audit reports consist of? What was your role in overseeing them? If you discovered an issue, what action would then be taken? : credit card batches, folio data, daily revenue. reconciled ledgers for corrections as needed. reported additional concerns to GM",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): How many team members did you need to train on Stay N Touch? : 5",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): What was the timeframe that you worked on the launch and training of Stay N Touch? : 2 months",
#     "Carlyle Suites, Commune Hotels and Resorts (Front Office Manager): What steps did you take in your efforts to properly create budgetary reports as well as seeing clear allocation expenses? : coded employees to the correct job codes, coded expenses to the correct job codes",
#     "Kimpton Hotels & Restaurants - Palomar (Manager on Duty): Would the correct title be Kimpton Hotels & Restaurants – Palomar; or should the Palomar be excluded? : Hotel Palomar, Kimpton...",
#     "Kimpton Hotels & Restaurants - Palomar (Manager on Duty): How did you form and maintain the successful relationships with Loyalty members? : remembering them and their preferences, using their names, offered upgrades upon check in",
#     "Kimpton Hotels & Restaurants - Palomar (Manager on Duty): Were you a main point of contact for guests? : can you clarify? i was the main point of escalation during my shifts",
#     "Kimpton Hotels & Restaurants - Palomar (Manager on Duty): How did you ensure Coyle Standards were utilized? : I followed the service standard guide at check in taking no deviations",
#     "Kimpton Hotels & Restaurants - Palomar (Manager on Duty): What was the impact of your recommendations for customer service improvements? : overall professionalism improvement of staff , more positive reviews and surveys upon check out",
#     "Kimpton Hotels & Restaurants - Palomar (Manager on Duty): Was there an increase in social media engagement as a result of you managing the account? : engagement was high as the Property was #2 on Trip Advisor. mgmt response time improved which is a direct correlation to being viewed positively resulting in more reservations."
#   ],
#   "education": [
#     "On your resume, you have that you received your Bachelor of Science in Hotel Management. However, on your questionnaire, you responded that Hospitality was your area of study. Which of these would be the correct area of study to put next to your B.S. degree from University of the West Indies? : Hotel Management"
#   ],
#   "skills": [],
#   "other_experience":[
#     "In the questionnaire, you mentioned that you were expecting your Property Management license in 2020. Was this achieved in 2020, or is it something in progress? : in progress.",
#     "Is your Alcoholic Beverage Regulation Administration – Manager’s License still active? : yes through april 2021"
#   ]
# }
# 4 {
#   "personal_info": [
#     "Is there anything not listed on your questionnaire, current resume, or the questions below that you feel is important for me to know/that you would like to be highlighted on your new resume? : Please highlight that i have a Scrum master certification and experience with Waterfall, Agile and Kanban methodologies.",
#     "What are you most unhappy about with your current resume? : It's too simple and plain."
#   ],
#   "work_experience": [
#     "Senior Programmer Analyst, FIS Global - What did your role in estimating requests from clients and working on improving the product and the implementation process entail? : 1.Estimating requests included analyzing the request from client, researching the existing process or set up and estimating the scope, time, assumptions and constraints for it.\n2. Created many documents and internal tools to make the implementation process more efficient. \n3.I have suggested many changes and potential issue fixes for updating the product.",
#     "Senior Programmer Analyst, FIS Global - What does your role in working on upgrading the Demo set up with Gateway API access entail? : I worked on adding seamless access to the existing Demo sites.",
#     "Senior Programmer Analyst, FIS Global - What does your role in working in a Kanban team to upgrade Telephone payments entail? : I was a part time scrum master and technical person for the Kanban team. For all the existing clients the telephone payments were updated with 'voice recognition' option.",
#     "Senior Programmer Analyst, FIS Global - What did your role in removing team impediments on a daily basis to allow the team to complete deliverables on time entail? Any notable examples? : 1. When there was an issue in a payment processing not working, i correctly guessed the processor side was not set up properly and the issue was not on our side. \n2. I have helped out with how the product works and feasibility of new changes. \n3.  helped with identifying the changes that can be done at a high level or unique for a specific console or a service for a client.",
#     "Senior Programmer Analyst, FIS Global - What did your role in facilitating team and cross-team Retrospectives to build good working relationships among different agile teams entail? : As a technical person and senior member i helped with the sharing and understanding of knowledge of various payment options, helped to get rid of impediments.",
#     "Senior Programmer Analyst, FIS Global - What did your role in collaborating with members of the Product, Sales and Development Teams to develop and maintain Product Backlogs entail? : I have identified many product level defects, issues and created the scope, need for changes. \nI have worked with the sales team in setting up demo sites and understanding of the product's latest updates.",
#     "Senior Programmer Analyst, FIS Global - What did your role in mentoring your team entail? How many people were you responsible for mentoring/supervising? : i have mentored more than 10 new team members. Even now i help out with the understanding and issues related to Single sign on, seamless access and APIs.",
#     "Senior Programmer Analyst, FIS Global - What did your role in prioritizing and validating requirements entail? : As a senior member of the team i have a good idea of what can and cannot be done in the existing framework. So i make decisions about adding a constraint or routing the request for product changes or specifying some thing cannot be done based on the nature of the request.",
#     "Senior Programmer Analyst, FIS Global - What did your role in maintaining the task board on TFS entail? : I have helped with updating adding user stories, maintaining the hours for each specific entry/client.",
#     "Senior Programmer Analyst, FIS Global - What did your role in coordinating product backlog grooming and story estimation with product owners entail? : I helped to add/update user stories and prioritizing the backlog.",
#     "Senior Programmer Analyst, FIS Global - What did your role in setting up different consoles for payments entail? : Setting up consoles for clients based on their requirements is the basic part of our implementation process. It includes biller console used by client customer service personnel, Customer console used by enrolled users, Quick pay used by end users for one-time payments, telephone payments.",
#     "Senior Programmer Analyst, FIS Global - What did your role in working with scrum teams attending various sprint meetings and providing technical help as SME entail? : Daily sprints were useful in sharing the details of everyone's progress and finding out if there was more than one person was facing similar issue or problems and identifying the potential major changes or defects. \nAs an SME i helped out with technical details and explaining the constraints or required  modifications to non-technical team members.",
#     "Senior Programmer Analyst, FIS Global - What did your work with product customizations, defect fixes, Single sign on, IVR Phone payments set up, and credit and debit processing entail? : 1. Product customization includes updating the UI, error messages, content for each client based on their requirements.\n2.Defect fixes includes fixing issues based on QA or client feedback\n3. Single sign on is setting up seamless login from the clients website to our billing website.\n4.IVR/phone payments includes setting up of telephone payment flow with English and/or Spanish wordings.\n5.Credit/Debit processing set up is to get the data for credit or debit processing details and set it up for that client, testing the payment process and the reports, ACH, AR files generated.",
#     "Senior Programmer Analyst, FIS Global - What did your role in the creation of demo sites for clients entail? : I have created demo sites for different categories of potential clients including insurance companies, medical billing, gas, water ,electric billing, government counties.",
#     "Programmer Analyst, FIS Global - What did your role in single sign on set up for biller for different consoles with API, ESLAPI and Gateway entail? : ESLAPI is a time consuming process that was followed previously for single sign on. i learnt and ended up being the only person in the implementation team to have good knowledge of this process.\nAPIs and Gateway set up are done by another team and we just update the set up on our side with minor changes to enable single sign on access.",
#     "Programmer Analyst, FIS Global - What did your role in parsing and loading bills that come as a CDF into database to present on websites entail? : The bill information is sent by the client in data files. These are loaded into database on our side and presented to the end users in the format of the physical bill. I have worked on this process.",
#     "Programmer Analyst, FIS Global - What did your role in helping Project managers to understand the existing product and conversion options entail? : As new projects or requests are assigned to project managers, some of them have difficulty explaining the work flow or constraints or procedure to the clients. I have helped them out during this time.",
#     "Programmer Analyst, FIS Global - What did your role in creating numerous documents and knowledge transfer sessions entail? : As and when i work or as we get upgraded to new process or UI  i have created and updated documents and shared with the team. This helps during KT sessions and easy knowledge sharing.",
#     "Programmer Analyst, FIS Global - What did your role in interviewing and hiring new members entail? How many people were you responsible for supervising? : i have supervised 5-8 people. I do the general and technical part of the interview.",
#     "Programmer Analyst, FIS Global - What did your role in setting up UI for different clients based on their original website entail? : We check the clients existing website and set up the payment processing UI to have similar look and feel.",
#     "Programmer Analyst, FIS Global - What did your role in setting up and creating ACH files, Account reconciliation files for different payment options including bank, credit card, pin less debit and signature debit entail? : 1. Based on the client's requirements, the different types of payments are set up with different payment processors for bank, credit, debit, pin less debit payments. The bank or the processor send us the details which are set up on our databases and payment flow is tested. \n2. ACH files are automatically generated according to NACHA standards. \n3. Account reconciliation files are sent to the client at the end of each day with details of the entire day's payments. This file format is decided by the biller and customized according to their requirements."
#   ],
#   "education": [],
#   "skills": [],
#   "other_experience": [
#     "Just a note: our data-driven research shows that a one-page resume with a focus on impact in your current/past roles is ideal for the types of positions you’re interested in so that employers can see at a glance how greatly you will benefit their organization, with your most recent experience being the most featured. Most of the questions below are aimed at getting the most detail possible about your various roles and duties, with a focus on impact, so that I can convey not just WHAT you do, but why what you do is so valuable. So as much specific detail as you can provide is greatly appreciated! (To give a more specific example, ideally we want most of our resume bullets to be formatted in a “Performed x duty for y purpose, achieving z results” type of a structure) : 1.Created multiple documents for easy understanding and knowledge of the system for technical and non-technical users 2.Mentored and helped team members, project managers, Customer support personnel to help them understand the product. 3. Worked with sales team to do a good demo of the product for potential billers. 3. Suggested changes for product to improve the UI and processing."
#   ]
# }
# 5 {
#   "personal_info": [
#     "We typically suggest a client’s summaries of their resume because it leaves space for accomplishments that occurred during your professional experiences. Are you comfortable with this? Answer: I prefer starting earlier than 2007 to capture all my banking experiences.",
#     "Is there anything else you would like to share that is not mentioned on your resume? Answer: I am also a Real Estate Sales Agent with a Broker's License. I have been actively selling real estate services since 2001. Can this be incorporated into my resume for jobs that are real estate related."
#   ],
#   "work_experience": [
#     "Senior Collateral Audit Specialist: Identify, communicate, cite, and track exceptions for management reporting purposes...report and correct documentation deficiencies post-audit. What were the strategies you’ve used, and what was the actual goal and target in figures/numbers? Answer: Strategies used was to thoroughly explore all avenues and options in researching information, problem solving, and paying strong attention to details by analyzing the documents and being a forward, proactive thinker. I have audited multiple loans discovering and mitigating risks found in these documentation for the bank.",
#     "Senior Collateral Audit Specialist: Process collateral releases and complicated research/maintenance requests from lending units. How many reports and documentation have you worked on? What was the impact of these initiatives? Answer: I have audited multiple loans discovering and mitigating risks found in these documentation for the bank.",
#     "Banking Officer/Loan Review Specialist: Communicate audit findings by preparing reports and discussing findings with management. What are the tools and techniques you’ve utilized that helped you perform these tasks? Answer: Analytical skills with attention to detail, problem-solving, & researching skills.",
#     "Banking Officer/Loan Review Specialist: Communicate audit findings by preparing reports and discussing findings with management. What were the actual goal and targets in figures/numbers? Answer: Analytical skills with attention to detail, problem-solving, & researching skills.",
#     "Loan Servicing Booking and Payment Processor Specialist: Performed special projects as needed. What were these projects? Were there any significant impact of these projects to the company? Answer: Projects requiring more dedicated research to apply payments or missing payments per request of Relationship Managers or Supervisors. Impact resulted in satisfied customers when payments were properly found and applied to accounts."
#   ],
#   "education": [],
#   "skills": [],
#   "other_experience": [
#     "Please provide a 3 to 5 sentence overview of any achievements, success stories, or impact you have made in your entire professional career? What were the strategies and duties you’ve done that made you achieve these accomplishments? Answer: The impact I have made in my professional career is discovering errors and exceptions in legal documentation and preventing and reducing risks and monetary loss to the bank or institutions."
#   ]
# }
# 6 {
#   "personal_info": [
#     "1: Your current LinkedIn URL is not customized. Customized URLs are important because they look more professional and make your profile more accessible to recruiters and hiring managers. The LinkedIn URL Linkedin.com/in/______ is available. I am going to add that URL to your resume. We recommend you update your URL on your LinkedIn account to this. Does this make sense? : I updated url to www.linkedin.com/in/lonnielehman"
#   ],
#   "work_experience": [
#     "Lutheran Life Communities - Corporate Director (IT): How were you able to manage and analyze $3M+ IT budgets for the entire organization? What actions you have to perform during this? : I worked with the organization to determine what hardware, software, services were going to be used in the next fiscal year. Created a budget for all spending, l and reviewed the budget on a monthly basis to identify any discrepancies and create a report for my immediate supervisor identifying the discrepancy, what if anything could be done about it, and whether this was a planned or unplanned expenditure.",
#     "Lutheran Life Communities - Corporate Director (IT): Can you please elaborate more information on designing, reviewing, and implementing technology for staff and residents? What does you mean by new addition in Arlington Heights, IL? : This building was Greenfield or built from the ground up new. I identify where every cable drop would be placed, where all of the access points would go, which equipment would be allocated to each office and area, Equipment allocation for the MDF and each IDF. I selected the phone system, I was responsible for overseeing the low voltage contractor. Installation, configuration of all telephones, servers, computers, networking equipment, POS (point of sale) The number of printers purchased and where they would go, fax machines, wireless communication devices phones, and nurse call. \n\nFor Arlington Heights (which was a remodel) identify placement of all the wireless access points, assisted in the design and implementation of the door access systems, nurse call systems, rerouting all outside communication lines, Office equipment and peripheral placement, equipment allocation for each IDF.",
# ...
#     "JLM Couture – Raw Materials and Production Assistant (April 2021 – Present): What steps/software/skills were involved in implementing superior 'organizational systems'? Can you provide any hard numbers/stats that demonstrate how these systems were 'better'? - I used excel to create dashboards with all of the stats of the RMs so we knew buying dates based on lead time or other variables",
#     "JLM Couture – Raw Materials and Production Assistant (April 2021 – Present): Did you work with and/or lead any co-workers on any assignments? If so, how many co-workers, which assignments, and what leadership and/or collaboration skills/techniques/methods do you use to lead or work with them? - I help with the design team helping to produce a 30 gowns per season (4 months timeline) to show for our market where buyers come to buy the gowns. I’ve been asked personally by designers to work on their teams because of my precise skills and attention to detail. My role sets the tone for production and how slow or fast we can produce things. I work on a team of 5",
#     "JLM Couture – Raw Materials and Production Assistant (April 2021 – Present): How often did you interact and work with higher-ranking personnel? - Constantly - they often come to me for help with any issues or questions they have",
#     "JLM Couture – Raw Materials and Production Assistant (April 2021 – Present): What was your most challenging day or task at this occupation, and how successful were you at managing it? - There was little to no organization with the role. I’ve been successful at managing it because of how organized and precise I am. There are a lot of moving parts and I was able to balance all of the issues we were seeing and do see today.",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): Which specific software and skills did you use to assist in 'making orders for buying decisions'? How important were these orders and decisions? - We use a program called Exenta. These orders are very important because they control what we can design and make for the season",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): How many 1-on-1 consultations did you lead/engage in in a typical month? How successful are these consultations? - 12-15. In constantly doing 1 on 1 consultations or having meetings discussing",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): What steps/software skills did you utilize to manage inventory orders? - Excel, one note, google docs. I use a lot of spreadsheets and metrics/data for my charts",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): How often do you liaison between fabrics and clients and for what projects/assignments do you liaise with these departments? - I act as a liaison between vendors and our projects (orders) at the factory. I work between the design and production departments",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): Did you work with and/or lead any co-workers on any assignments? If so, how many co-workers, which assignments, and what leadership and/or collaboration skills/techniques/methods do you use? - I work with a team of 5- we balance the PLM (product life management) of our orders and I emphasize on raw materials",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): How often did you interact and work with higher-ranking personnel? - Constantly- at least 3 times a week between the COO, CFO, CRO, and designers",
#     "Mood Fabrics – Textile Technician (October 2020 – Present): What was your most challenging day or task at this occupation, and how successful were you at managing it? - I’m a quick problem solver and fires are constantly coming up in my day to day. I use time management as well as being able to handle pressure by logically thinking out a solution",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): Can you describe any projects or assignments for which you used '3D rendering in CAD'? - I’ve worked at a canvas manufacturer where we used 3D modeling to create our products",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): How many projects would you work on in a typical year? Which project or projects were the most successful? - We have high volume orders which we are constantly managing while working on development for new seasons",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): With how many clients did you have 1-on-1 consultations in a typical month or year? How did these engagements help the company? - About 15 a month. Yes, these consultations help because we are able to communicate anything that needs to be done",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): What steps/software/skills were involved in developing and implementing 'time management processes'? Can you provide any hard numbers/stats that demonstrate how these improved the rate at which high-volume projects were completed? - Excel- I don’t have any hard numbers",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): How were machine operation and technical sewing skills involved? Did they play a part of any projects? If so, which projects? - This is a transferable skill because this gives me a strong base of garment construction and how RMs play a role in that",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): How successful were you at managing inventory orders? How did this help the company? - Successful- due to my organizational skills I was able to stick to our given timelines or manage gowns getting to be produced quickly",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): Did you work with and/or lead any co-workers on any assignments? If so, how many co-workers, which assignments, and what leadership and/or collaboration skills/techniques/methods do you use to lead/work with them? - I was the lead of production in this role",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): How often did you interact and work with higher-ranking personnel? - Directly",
#     "Nautilux Custom Canvas – Assistant Technical Designer (February 2016 – October 2020): What was your most challenging day or task at this occupation, and how successful were you at managing it? - Managing deadlines. I was successful by prioritizing projects"
#   ],
#   "education": [],
#   "skills": [],
#   "other_experience": []
# }
# 988 {
#   "personal_info": [
#     "What are you typically known for by your colleagues? Being a team-player, easy to get along with, can take constructive criticism,Adaptable, competent and efficient.",
#     "What do you consider your superhero abilities professionally, or what have you performed exceptionally well in your roles? I have a background working with people where I have spent years improving my communication and interpersonal skills. I realized that my personality is a great fit for sales, so I have spent the last three months going through an intensive online course in technology sales development.",
#     "What do you want to be known for in your career, professional field, and/or by your colleagues? I want to be known for my strong work ethic and my ability tackle any goal or task. Regardless of the obstacle in front of me. I willing to go out my way to help somebody without seeking anything in return.",
#     "Where do you want to ideally be next? I see myself in 5 years managing a sales team and moving up the corporate ladder to achieve goals unreachable."
#   ],
#
#   "work_experience": [
#     "Describe your experience related to Accounts Prospecting - When I worked for Vivint smart homes knocking outside I would carefully research the customer profile and home to see if the prospect was qualified for our security systems.",
#     "Describe your experience related to Communication Skills - I have used literally my whole life from serving my team at Whataburger to knocking on hundreds of doors for Vivint to communicate professionally to close accounts.",
#     "Describe your experience related to Client Services - I would assist existing Vivint customers who were due for an upgrade or needed new equipment to replace their old outdated equipment.",
#     "Describe your experience related to Solutions Development - I would provide solutions for customers while working with Vivint to create a solution for their problems such as Security cameras, alarm systems, motion detectors, etc.",
#     "Describe your experience related to Automated Outreach Campaigns - I have experience obtained from CourseCareers creating a spreadsheet in Excel. Creating a sales cadence using sales data to create a prospect list for the final project to reach out to high-level executives and C-level executives to contact via email and LinkedIn to setup a partnership with CourseCareers to hire entry-level or internships."
#   ],
#
#   "education": [],
#
#   "skills": [
#     "Check all keywords which relate to your professional experience in any way and leave out the ones you don’t have anything to do with, or have already shared sufficient information concerning the keyword. Accounts Prospecting, Solutions Development, Client Services, Automated Outreach Campaigns, Communication Skills."
#   ],
#
#   "other_experience": []
# }
# 989 {
#   "personal_info": [
#     "Is the resume you uploaded to the platform current? If not, please tell me the missing company name(s), position titles(s) and the start and end month/years that are missing from the resume.: I believe it is up to date.  However, I have had a lot of different roles over the years, even though I've been with the same organization.  I may have squashed some of those together to save space in the version I sent you.  I don't recall which one it was.  I think I still have the older one also, so I believe I can forward whichever one you don't have.",
#     "What are you most unhappy about with your current resume?: I think it needs a professional summary, and I need to switch around the order/placement of some of the information.  I don't think it sells me very well.",
#     "Do you want this resume to be 1 page long or 2 pages long?: No strong preference.  If I can say everything in one, that's fine.  If I need two, I'm okay with that.  I'd like to hear your thoughts on the question.",
#     "Your current LinkedIn URL is not customized. Customized URLs are important because they look more professional and make your profile more accessible to recruiters and hiring managers. The LinkedIn URL Linkedin.com/in/william-inden is available. I am going to add that URL to your resume. We recommend you update your URL on your LinkedIn account to this. Does this make sense?: Yes, although I'm not sure how to do that.  I assume it's something I'll be able to figure out."
#   ],
#   "work_experience": [
#     "Philadelphia DA’s Office – Assistant DA in Charging Unit (2023-present) How many cases and warrants do you review and charge or decline in a typical week?: I've only been there for a few weeks.  I'll get back to you on this.",
#     "Philadelphia DA’s Office – Assistant DA in Charging Unit (2023-present) Can you provide the names any of these new technical systems?: Premier One, Evidence.com, PARS (not sure what that stands for -- it's the system the police and DA office uses to charge), Juvenile E-file",
#     "Philadelphia DA’s Office – Assistant DA in Charging Unit (2023-present) How have the difficult judgment calls at this position enhanced your legal skills and prepared you for a career in another part of the legal field?: Will answer more later.",
#     "Philadelphia DA’s Office – Youth Violent Offender Unit Prosecutor (2020-2022) How high was the percentage of court transfers (for example, “roughly 70%,” “roughly 80%”)?",
#     "Philadelphia DA’s Office – Youth Violent Offender Unit Prosecutor (2020-2022) Can you provide any hard numbers, statists, or additional specifics to demonstrate how you minimized public safety concerns?",
#     "Philadelphia DA’s Office – Youth Violent Offender Unit Prosecutor (2020-2022) How many cases did you handle in a typical month? What were their typical outcomes?",
#     "Philadelphia DA’s Office – Youth Violent Offender Unit Prosecutor (2020-2022) How many prosecutors did you mentor during your time here? What did you learn from this experience?",
#     "Philadelphia DA’s Office – Pretrial Unit ADA (2017-2020) How many criminal cases did you resolve via guilty plea in a typical week or month or year?",
#     "Philadelphia DA’s Office – Pretrial Unit ADA (2017-2020) How many motions to quash did you win in a typical week or month or year?",
#     "Philadelphia DA’s Office – Pretrial Unit ADA (2017-2020) How did you ensure fair treatment for defendants and accountability for probation violators?",
#     "Philadelphia DA’s Office – Pretrial Unit ADA (2017-2020) How have these negotiation and litigation experienced prepared you for a career in another part of the legal field?",
#     "Philadelphia DA’s Office – Major Trials, YVO, Juvenile, Pretrial, Municipal Court, and Charging Units (2001-2005, 2017-present) What is your official title at this office?",
#     "Philadelphia DA’s Office – Major Trials, YVO, Juvenile, Pretrial, Municipal Court, and Charging Units (2001-2005, 2017-present) Do you work as an independent contractor or are you an employee of the DA office?",
#     "Philadelphia DA’s Office – Major Trials, YVO, Juvenile, Pretrial, Municipal Court, and Charging Units (2001-2005, 2017-present) Can you provide any hard numbers, statistics, or additional specifics concerning the prosecution and defense success rates?",
#     "Philadelphia DA’s Office – Major Trials, YVO, Juvenile, Pretrial, Municipal Court, and Charging Units (2001-2005, 2017-present) Can you provide the names of any software/programs you used to prepare charging documents?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) What leadership positions did you have on the task force? How many others were on the task force?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) Did you work with and/or lead others on the task forces? If so, how many, and for which responsibilities?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) What leadership and/or collaboration skills/techniques/methods did you use at this occupation?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) What parts of the violence reduction strategy did you help develop and implement? What were the most successful aspects of said parts?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) Can you provide any statistics/numerical data to demonstrate the “dramatic decrease of shootings and homicides”?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) How many cases did you refer to the federal authorities in a typical month? How did this help the DAO?",
#     "Philadelphia DA’s Office – Gun Violence Task Force (2013-2016) Did you prosecute “dozens of unlawful straw purchasers” weekly, monthly, or yearly?",
#     "Philadelphia DA’s Office – Special Investigations Unit (2009-2012) How many local cases did you prosecute in a typical month or year? How many federal cases did you prosecute in a typical month or year?",
#     "Philadelphia DA’s Office – Special Investigations Unit (2009-2012) How successful were you at investigating municipal corruption, police misconduct, election fraud, and illegal gambling? Can you provide any examples or statistical data to demonstrate this success?"
#   ],
#   "education": [],
#   "skills": [],
#   "other_experience": []
# }
# 990 {
#   "personal_info": [],
#   "work_experience": [],
#   "education": [],
#   "skills": [],
#   "other_experience":[]
# }
# 991 {
#   "personal_info": [],
#   "work_experience": [],
#   "education": [],
#   "skills": [],
#   "other_experience": []
# }

# %%
followup_df['gpt4o_response'] = res

# %%
followup_df
# Out:
#                      order_id  \
# 0    5ff575580438d7001357b80e
# 1    5ffc729d0d564400125bcc31
# 2    5ff893a5dd2f9600139ab166
# 3    5ff8945fdd2f9600139ab16a
# 4    5ff7cd94dd2f9600139ab137
# ..                        ...
# 987  63ab370268746a00137ab45e
# 988  63c57f42d28912001b92f8fb
# 989  63c71397a837f6001a206708
# 990  63c57a469cac930013a54719
# 991  63c99ddaa837f6001a239c0a
#
#                               additional_questionnaire  \
# 0    {"1: Follow Up Questions ": {"1: Your current ...
# 1    {"1: Follow Up Questions ": {"1: Your current ...
# 2    {"1: Follow Up Questions ": {"1: GENERAL: In o...
# 3    {"1: Follow Up Questions ": {"1: Your current ...
# 4    {"1: Follow Up Questions ": {"1: Just a note: ...
# ..                                                 ...
# 987  {"1: Follow Up Questions": {"1: Your current L...
# 988  {"2: General Questions": {"1: What are you typ...
# 989  {"1: Follow Up Questions": {"1: Is the resume ...
# 990                                                 {}
# 991                                                 {}
#
#                                         gpt4o_response
# 0    {\n  "personal_info": [\n    "1: Your current ...
# 1    {\n  "personal_info": [\n    "Your current Lin...
# 2    {\n  "personal_info": [\n    "GENERAL: In opti...
# 3    {\n  "personal_info": [\n    "1: Your current ...
# 4    {\n  "personal_info": [\n    "Is there anythin...
# ..                                                 ...
# 987  {\n  "personal_info": [\n    "Your current Lin...
# 988  {\n  "personal_info": [\n    "What are you typ...
# 989  {\n  "personal_info": [\n    "Is the resume yo...
# 990  {\n  "personal_info": [],\n  "work_experience"...
# 991  {\n  "personal_info": [],\n  "work_experience"...
#
# [992 rows x 3 columns]

# %%
### split the 5 categories into 5 individual columns
def _followup_explode(row, section_name):
    try: 
        json_row = json.loads(row)

        if section_name in json_row.keys():
            return json_row[section_name]
        else:  # some resume's don't have certain fields.
            return {}
    except: ## when gpt did not return json 
        print ("CORRUPT FOLLOWUP CATEGORIZATION")
        return "CORRUPT FOLLOWUP CATEGORIZATION"

    
df_explode = followup_df.copy()
df_explode['personalinfo'] = df_explode.gpt4o_response.apply(lambda x: _followup_explode(x, "personal_info"))
df_explode['workexp'] = df_explode.gpt4o_response.apply(lambda x: _followup_explode(x, "work_experience"))
df_explode['education'] = df_explode.gpt4o_response.apply(lambda x: _followup_explode(x, "education"))
df_explode['otherexp'] = df_explode.gpt4o_response.apply(lambda x: _followup_explode(x, "other_experience"))
df_explode['skills'] = df_explode.gpt4o_response.apply(lambda x: _followup_explode(x, "skills"))

df_explode.columns
# Out:
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# CORRUPT FOLLOWUP CATEGORIZATION
# Index(['order_id', 'additional_questionnaire', 'gpt4o_response',
#        'personalinfo', 'workexp', 'education', 'otherexp', 'skills'],
#       dtype='object')

# %%
df_explode = df_explode[df_explode.personalinfo!='CORRUPT FOLLOWUP CATEGORIZATION'].reset_index(drop=True) # remove 6 resumes with corrupt json parsing
df_explode.to_csv('followup_q&a_categorized.csv')
